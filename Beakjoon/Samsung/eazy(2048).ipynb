# %%
# Link: https://www.acmicpc.net/problem/12100

# %%
import copy
def up(tmp_board):
    for j in range(N):
        pointer = 0
        for i in range(1, N):
            if tmp_board[i][j]:
                tmp = board[i][j]
                tmp_board[i][j] = 0
                
                if tmp_board[pointer][j] == 0:
                    tmp_board[pointer][j] = tmp
                
                elif tmp_board[pointer][j] == tmp:
                    tmp_board[pointer][j] *= 2
                    pointer += 1
                
                else:
                    pointer += 1
                    tmp_board[pointer][j] = tmp
    
    return tmp_board

def down(tmp_board):
    for j in range(N):
        pointer = N-1
        for i in range(N-2,-1, -1):
            if tmp_board[i][j]:
                tmp = board[i][j]
                tmp_board[i][j] = 0
            
                if tmp_board[pointer][j] == 0:
                    tmp_board[pointer][j] = tmp
                
                elif tmp_board[pointer][j] == tmp:
                    tmp_board[pointer][j] *= 2
                    pointer -= 1
                
                else:
                    pointer -= 1
                    tmp_board[pointer][j] = tmp
    
    return tmp_board
        
def left(board):
    n = N
    for i in range(n):
        pointer = 0
        for j in range(1, n):
            if board[i][j]:
                tmp = board[i][j]
                board[i][j] = 0
                if board[i][pointer] == 0:
                    board[i][pointer] = tmp
                elif board[i][pointer]  == tmp:
                    board[i][pointer] *= 2
                    pointer += 1
                else:
                    pointer += 1
                    board[i][pointer]= tmp
    return board

# RIGHT
def right(board):
    n =N
    for i in range(n):
        pointer = n - 1
        for j in range(n - 2, -1, -1):
            if board[i][j]:
                tmp = board[i][j]
                board[i][j] = 0
                if board[i][pointer] == 0:
                    board[i][pointer] = tmp
                elif board[i][pointer]  == tmp:
                    board[i][pointer] *= 2
                    pointer -= 1
                else:
                    pointer -= 1
                    board[i][pointer] = tmp
    return board


# 입력받기
def dfs(board, cnt):
    if cnt == 5:
        return max(map(max, board))
    
    return max(dfs(up(copy.deepcopy(board)), cnt + 1), 
               dfs(down(copy.deepcopy(board)), cnt + 1), 
               dfs(left(copy.deepcopy(board)), cnt + 1), 
               dfs(right(copy.deepcopy(board)), cnt + 1))


if __name__ == "__main__":
    #N = int(input())
    #board = [list(map(int, input().split())) for _ in range(N)]
    N = 3
    board = [[2, 2, 2],
             [4, 4, 4],
             [8, 8, 8]]
    
    cnt = 0
    print(dfs(board, cnt))
    #tmp_board = up(board)
    #print(tmp_board)
# Out:
# 16

# %%
# Out:
# 16

# %%
print(max(map(max, A)))
# Out:
# 16

# %%
def up(board):
    for j in range(N):
        pointer = 0
        for i in range(1, N):
            if board[i][j]:
                tmp = board[i][j]
                board[i][j] = 0
            
                if board[pointer][j] == 0:
                    board[pointer][j] = tmp
                    
                elif board[pointer][j] == tmp:
                    board[pointer][j] = tmp * 2
                    pointer = pointer + 1
                else:
                    pointer = pointer + 1
                    board[pointer][j] = tmp

    return board

def down(board):
    for j in range(N):
        pointer = N - 1
        for i in range(N-2, -1, -1):
            if board[i][j]:
                tmp = board[i][j]
                board[i][j] = 0
                
                if board[pointer][j] == 0:
                    board[pointer][j] = tmp
                    
                elif board[pointer][j] == tmp:
                    board[pointer][j] = tmp * 2
                    pointer = pointer - 1
                else:
                    pointer = pointer - 1
                    board[pointer][j] = tmp
                    
    return board


def left(board): 
    for i in range(N):
        pointer = 0
        for j in range(1, N):
            if board[i][j]:
                tmp = board[i][j]
                board[i][j] = 0

                if board[i][pointer] == 0:
                    board[i][pointer] = tmp
                        
                elif board[i][pointer] == tmp:
                    board[i][pointer] = tmp * 2
                    pointer = pointer + 1
                    
                else:
                    pointer = pointer + 1
                    board[i][pointer] = tmp
                
    return board

def right(board): 
    for i in range(N):
        pointer = N-1
        for j in range(N-2, -1, -1):
            if board[i][j]:
                tmp = board[i][j]
                board[i][j] = 0

                if board[i][pointer] == 0:
                    board[i][pointer] = tmp
                        
                elif board[i][pointer] == tmp:
                    board[i][pointer] = tmp * 2
                    pointer = pointer - 1
                    
                else:
                    pointer = pointer - 1
                    board[i][pointer] = tmp
                
    return board

import copy
def DFS(board, cnt):
    if cnt == 5:
        return max(map(max, board))
    
    tmp = max(DFS(up(copy.deepcopy(board)), cnt+1), 
              DFS(down(copy.deepcopy(board)), cnt+1), 
              DFS(left(copy.deepcopy(board)), cnt+1),
              DFS(right(copy.deepcopy(board)), cnt+1))
    
    return tmp
if __name__ == "__main__":
    N = int(input())
    board = [list(map(int, input().split())) for _ in range(N)]

    cnt = 0
    print(DFS(board, cnt))
# Out:
# 16
